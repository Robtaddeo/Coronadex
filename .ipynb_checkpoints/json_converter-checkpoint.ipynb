# %%
import yfinance as yf
import pandas as pd
import time
import datetime
import json

# %%
def convert_timestamp(item_date_object):
    if isinstance(item_date_object, (datetime.date, datetime.datetime)):
        return item_date_object.timestamp() * 1000

# %%
def get_stock_data_json(ticker):
    stock = yf.Ticker(ticker)
    hist = stock.history(period="YTD")
    hist.reset_index(inplace=True)
    hist['Volume'] = hist['Volume'] / 1000000
    hist = hist[['Date', 'Close', 'Volume']] 
    out = []
    close = {
        "name": "Price",
        "data": [],
        "type" : "line",
        "color" : "#ffa600"
    }
    volume = {
        "name": "Volume",
        "data": [],
        "type": "column",
        "color" : "#70a1ff",
        "yAxis" : 1,
        
    }
    for index, row in hist.iterrows():
        close['data'].append([row['Date'], row['Close']])
        volume['data'].append([row['Date'], row['Volume']])
        
    out.append(volume)
    out.append(close)
    json_out = json.dumps(out, default=convert_timestamp)
    with open('./client/public/Data/' + ticker + '.json', 'w') as f:
        f.write(json_out)

# %%
stocks = [
    {
        "name" : "Alphabet",
        "ticker" : "GOOG"
    },
    {
        "name" : "S&P 500 Spyder ETF",
        "ticker" : "SPY"
    },
    {
        "name" : "Dow Jones Industrial Average",
        "ticker" : "DJI"
    },
    {
        "name" : "Apple",
        "ticker" : "AAPL"
    },
    {
        "name" : "Nike",
        "ticker" : "NKE"
    }
]

# %%
def get_all_spx_tickers():
    df = pd.read_csv('./Data/constituents.csv')
    return df

df = get_all_spx_tickers()
df
# Out:
#     Symbol                    Name                  Sector
# 0      MMM              3M Company             Industrials
# 1      AOS         A.O. Smith Corp             Industrials
# 2      ABT     Abbott Laboratories             Health Care
# 3     ABBV             AbbVie Inc.             Health Care
# 4      ACN           Accenture plc  Information Technology
# ..     ...                     ...                     ...
# 500    XYL              Xylem Inc.             Industrials
# 501    YUM         Yum! Brands Inc  Consumer Discretionary
# 502    ZBH  Zimmer Biomet Holdings             Health Care
# 503   ZION           Zions Bancorp              Financials
# 504    ZTS                  Zoetis             Health Care
#
# [505 rows x 3 columns]

# %%
spx_stonks = []
for index, row in df.iterrows():
    spx_stonks.append({
        "name" : row["Name"],
        "ticker" : row["Symbol"]
    })
    
spx_stonks
# Out:
# [{'name': '3M Company', 'ticker': 'MMM'},
#  {'name': 'A.O. Smith Corp', 'ticker': 'AOS'},
#  {'name': 'Abbott Laboratories', 'ticker': 'ABT'},
#  {'name': 'AbbVie Inc.', 'ticker': 'ABBV'},
#  {'name': 'Accenture plc', 'ticker': 'ACN'},
#  {'name': 'Activision Blizzard', 'ticker': 'ATVI'},
#  {'name': 'Acuity Brands Inc', 'ticker': 'AYI'},
#  {'name': 'Adobe Systems Inc', 'ticker': 'ADBE'},
#  {'name': 'Advance Auto Parts', 'ticker': 'AAP'},
#  {'name': 'Advanced Micro Devices Inc', 'ticker': 'AMD'},
#  {'name': 'AES Corp', 'ticker': 'AES'},
#  {'name': 'Aetna Inc', 'ticker': 'AET'},
#  {'name': 'Affiliated Managers Group Inc', 'ticker': 'AMG'},
#  {'name': 'AFLAC Inc', 'ticker': 'AFL'},
#  {'name': 'Agilent Technologies Inc', 'ticker': 'A'},
#  {'name': 'Air Products & Chemicals Inc', 'ticker': 'APD'},
#  {'name': 'Akamai Technologies Inc', 'ticker': 'AKAM'},
#  {'name': 'Alaska Air Group Inc', 'ticker': 'ALK'},
#  {'name': 'Albemarle Corp', 'ticker': 'ALB'},
#  {'name': 'Alexandria Real Estate Equities Inc', 'ticker': 'ARE'},
#  {'name': 'Alexion Pharmaceuticals', 'ticker': 'ALXN'},
#  {'name': 'Align Technology', 'ticker': 'ALGN'},
#  {'name': 'Allegion', 'ticker': 'ALLE'},
#  {'name': 'Allergan, Plc', 'ticker': 'AGN'},
#  {'name': 'Alliance Data Systems', 'ticker': 'ADS'},
#  {'name': 'Alliant Energy Corp', 'ticker': 'LNT'},
#  {'name': 'Allstate Corp', 'ticker': 'ALL'},
#  {'name': 'Alphabet Inc Class A', 'ticker': 'GOOGL'},
#  {'name': 'Alphabet Inc Class C', 'ticker': 'GOOG'},
#  {'name': 'Altria Group Inc', 'ticker': 'MO'},
#  {'name': 'Amazon.com Inc.', 'ticker': 'AMZN'},
#  {'name': 'Ameren Corp', 'ticker': 'AEE'},
#  {'name': 'American Airlines Group', 'ticker': 'AAL'},
#  {'name': 'American Electric Power', 'ticker': 'AEP'},
#  {'name': 'American Express Co', 'ticker': 'AXP'},
#  {'name': 'American International Group, Inc.', 'ticker': 'AIG'},
#  {'name': 'American Tower Corp A', 'ticker': 'AMT'},
#  {'name': 'American Water Works Company Inc', 'ticker': 'AWK'},
#  {'name': 'Ameriprise Financial', 'ticker': 'AMP'},
#  {'name': 'AmerisourceBergen Corp', 'ticker': 'ABC'},
#  {'name': 'AMETEK Inc.', 'ticker': 'AME'},
#  {'name': 'Amgen Inc.', 'ticker': 'AMGN'},
#  {'name': 'Amphenol Corp', 'ticker': 'APH'},
#  {'name': 'Anadarko Petroleum Corp', 'ticker': 'APC'},
#  {'name': 'Analog Devices, Inc.', 'ticker': 'ADI'},
#  {'name': 'Andeavor', 'ticker': 'ANDV'},
#  {'name': 'ANSYS', 'ticker': 'ANSS'},
#  {'name': 'Anthem Inc.', 'ticker': 'ANTM'},
#  {'name': 'Aon plc', 'ticker': 'AON'},
#  {'name': 'Apache Corporation', 'ticker': 'APA'},
#  {'name': 'Apartment Investment & Management', 'ticker': 'AIV'},
#  {'name': 'Apple Inc.', 'ticker': 'AAPL'},
#  {'name': 'Applied Materials Inc.', 'ticker': 'AMAT'},
#  {'name': 'Aptiv Plc', 'ticker': 'APTV'},
#  {'name': 'Archer-Daniels-Midland Co', 'ticker': 'ADM'},
#  {'name': 'Arconic Inc.', 'ticker': 'ARNC'},
#  {'name': 'Arthur J. Gallagher & Co.', 'ticker': 'AJG'},
#  {'name': 'Assurant Inc.', 'ticker': 'AIZ'},
#  {'name': 'AT&T Inc.', 'ticker': 'T'},
#  {'name': 'Autodesk Inc.', 'ticker': 'ADSK'},
#  {'name': 'Automatic Data Processing', 'ticker': 'ADP'},
#  {'name': 'AutoZone Inc', 'ticker': 'AZO'},
#  {'name': 'AvalonBay Communities, Inc.', 'ticker': 'AVB'},
#  {'name': 'Avery Dennison Corp', 'ticker': 'AVY'},
#  {'name': 'Baker Hughes, a GE Company', 'ticker': 'BHGE'},
#  {'name': 'Ball Corp', 'ticker': 'BLL'},
#  {'name': 'Bank of America Corp', 'ticker': 'BAC'},
#  {'name': 'Baxter International Inc.', 'ticker': 'BAX'},
#  {'name': 'BB&T Corporation', 'ticker': 'BBT'},
#  {'name': 'Becton Dickinson', 'ticker': 'BDX'},
#  {'name': 'Berkshire Hathaway', 'ticker': 'BRK.B'},
#  {'name': 'Best Buy Co. Inc.', 'ticker': 'BBY'},
#  {'name': 'Biogen Inc.', 'ticker': 'BIIB'},
#  {'name': 'BlackRock', 'ticker': 'BLK'},
#  {'name': 'Block H&R', 'ticker': 'HRB'},
#  {'name': 'Boeing Company', 'ticker': 'BA'},
#  {'name': 'Booking Holdings Inc', 'ticker': 'BKNG'},
#  {'name': 'BorgWarner', 'ticker': 'BWA'},
#  {'name': 'Boston Properties', 'ticker': 'BXP'},
#  {'name': 'Boston Scientific', 'ticker': 'BSX'},
#  {'name': 'Brighthouse Financial Inc', 'ticker': 'BHF'},
#  {'name': 'Bristol-Myers Squibb', 'ticker': 'BMY'},
#  {'name': 'Broadcom', 'ticker': 'AVGO'},
#  {'name': 'Brown-Forman Corp.', 'ticker': 'BF.B'},
#  {'name': 'C. H. Robinson Worldwide', 'ticker': 'CHRW'},
#  {'name': 'CA, Inc.', 'ticker': 'CA'},
#  {'name': 'Cabot Oil & Gas', 'ticker': 'COG'},
#  {'name': 'Cadence Design Systems', 'ticker': 'CDNS'},
#  {'name': 'Campbell Soup', 'ticker': 'CPB'},
#  {'name': 'Capital One Financial', 'ticker': 'COF'},
#  {'name': 'Cardinal Health Inc.', 'ticker': 'CAH'},
#  {'name': 'Carmax Inc', 'ticker': 'KMX'},
#  {'name': 'Carnival Corp.', 'ticker': 'CCL'},
#  {'name': 'Caterpillar Inc.', 'ticker': 'CAT'},
#  {'name': 'Cboe Global Markets', 'ticker': 'CBOE'},
#  {'name': 'CBRE Group', 'ticker': 'CBRE'},
#  {'name': 'CBS Corp.', 'ticker': 'CBS'},
#  {'name': 'Celgene Corp.', 'ticker': 'CELG'},
#  {'name': 'Centene Corporation', 'ticker': 'CNC'},
#  {'name': 'CenterPoint Energy', 'ticker': 'CNP'},
#  {'name': 'CenturyLink Inc', 'ticker': 'CTL'},
#  {'name': 'Cerner', 'ticker': 'CERN'},
#  {'name': 'CF Industries Holdings Inc', 'ticker': 'CF'},
#  {'name': 'Charles Schwab Corporation', 'ticker': 'SCHW'},
#  {'name': 'Charter Communications', 'ticker': 'CHTR'},
#  {'name': 'Chevron Corp.', 'ticker': 'CVX'},
#  {'name': 'Chipotle Mexican Grill', 'ticker': 'CMG'},
#  {'name': 'Chubb Limited', 'ticker': 'CB'},
#  {'name': 'Church & Dwight', 'ticker': 'CHD'},
#  {'name': 'CIGNA Corp.', 'ticker': 'CI'},
#  {'name': 'Cimarex Energy', 'ticker': 'XEC'},
#  {'name': 'Cincinnati Financial', 'ticker': 'CINF'},
#  {'name': 'Cintas Corporation', 'ticker': 'CTAS'},
#  {'name': 'Cisco Systems', 'ticker': 'CSCO'},
#  {'name': 'Citigroup Inc.', 'ticker': 'C'},
#  {'name': 'Citizens Financial Group', 'ticker': 'CFG'},
#  {'name': 'Citrix Systems', 'ticker': 'CTXS'},
#  {'name': 'CME Group Inc.', 'ticker': 'CME'},
#  {'name': 'CMS Energy', 'ticker': 'CMS'},
#  {'name': 'Coca-Cola Company (The)', 'ticker': 'KO'},
#  {'name': 'Cognizant Technology Solutions', 'ticker': 'CTSH'},
#  {'name': 'Colgate-Palmolive', 'ticker': 'CL'},
#  {'name': 'Comcast Corp.', 'ticker': 'CMCSA'},
#  {'name': 'Comerica Inc.', 'ticker': 'CMA'},
#  {'name': 'Conagra Brands', 'ticker': 'CAG'},
#  {'name': 'Concho Resources', 'ticker': 'CXO'},
#  {'name': 'ConocoPhillips', 'ticker': 'COP'},
#  {'name': 'Consolidated Edison', 'ticker': 'ED'},
#  {'name': 'Constellation Brands', 'ticker': 'STZ'},
#  {'name': 'Corning Inc.', 'ticker': 'GLW'},
#  {'name': 'Costco Wholesale Corp.', 'ticker': 'COST'},
#  {'name': 'Coty, Inc', 'ticker': 'COTY'},
#  {'name': 'Crown Castle International Corp.', 'ticker': 'CCI'},
#  {'name': 'CSRA Inc.', 'ticker': 'CSRA'},
#  {'name': 'CSX Corp.', 'ticker': 'CSX'},
#  {'name': 'Cummins Inc.', 'ticker': 'CMI'},
#  {'name': 'CVS Health', 'ticker': 'CVS'},
#  {'name': 'D. R. Horton', 'ticker': 'DHI'},
#  {'name': 'Danaher Corp.', 'ticker': 'DHR'},
#  {'name': 'Darden Restaurants', 'ticker': 'DRI'},
#  {'name': 'DaVita Inc.', 'ticker': 'DVA'},
#  {'name': 'Deere & Co.', 'ticker': 'DE'},
#  {'name': 'Delta Air Lines Inc.', 'ticker': 'DAL'},
#  {'name': 'Dentsply Sirona', 'ticker': 'XRAY'},
#  {'name': 'Devon Energy Corp.', 'ticker': 'DVN'},
#  {'name': 'Digital Realty Trust Inc', 'ticker': 'DLR'},
#  {'name': 'Discover Financial Services', 'ticker': 'DFS'},
#  {'name': 'Discovery Inc. Class A', 'ticker': 'DISCA'},
#  {'name': 'Discovery Inc. Class C', 'ticker': 'DISCK'},
#  {'name': 'Dish Network', 'ticker': 'DISH'},
#  {'name': 'Dollar General', 'ticker': 'DG'},
#  {'name': 'Dollar Tree', 'ticker': 'DLTR'},
#  {'name': 'Dominion Energy', 'ticker': 'D'},
#  {'name': 'Dover Corp.', 'ticker': 'DOV'},
#  {'name': 'DowDuPont', 'ticker': 'DWDP'},
#  {'name': 'Dr Pepper Snapple Group', 'ticker': 'DPS'},
#  {'name': 'DTE Energy Co.', 'ticker': 'DTE'},
#  {'name': 'Duke Energy', 'ticker': 'DUK'},
#  {'name': 'Duke Realty Corp', 'ticker': 'DRE'},
#  {'name': 'DXC Technology', 'ticker': 'DXC'},
#  {'name': 'E*Trade', 'ticker': 'ETFC'},
#  {'name': 'Eastman Chemical', 'ticker': 'EMN'},
#  {'name': 'Eaton Corporation', 'ticker': 'ETN'},
#  {'name': 'eBay Inc.', 'ticker': 'EBAY'},
#  {'name': 'Ecolab Inc.', 'ticker': 'ECL'},
#  {'name': "Edison Int'l", 'ticker': 'EIX'},
#  {'name': 'Edwards Lifesciences', 'ticker': 'EW'},
#  {'name': 'Electronic Arts', 'ticker': 'EA'},
#  {'name': 'Emerson Electric Company', 'ticker': 'EMR'},
#  {'name': 'Entergy Corp.', 'ticker': 'ETR'},
#  {'name': 'Envision Healthcare', 'ticker': 'EVHC'},
#  {'name': 'EOG Resources', 'ticker': 'EOG'},
#  {'name': 'EQT Corporation', 'ticker': 'EQT'},
#  {'name': 'Equifax Inc.', 'ticker': 'EFX'},
#  {'name': 'Equinix', 'ticker': 'EQIX'},
#  {'name': 'Equity Residential', 'ticker': 'EQR'},
#  {'name': 'Essex Property Trust, Inc.', 'ticker': 'ESS'},
#  {'name': 'Estee Lauder Cos.', 'ticker': 'EL'},
#  {'name': 'Everest Re Group Ltd.', 'ticker': 'RE'},
#  {'name': 'Eversource Energy', 'ticker': 'ES'},
#  {'name': 'Exelon Corp.', 'ticker': 'EXC'},
#  {'name': 'Expedia Inc.', 'ticker': 'EXPE'},
#  {'name': 'Expeditors International', 'ticker': 'EXPD'},
#  {'name': 'Express Scripts', 'ticker': 'ESRX'},
#  {'name': 'Extra Space Storage', 'ticker': 'EXR'},
#  {'name': 'Exxon Mobil Corp.', 'ticker': 'XOM'},
#  {'name': 'F5 Networks', 'ticker': 'FFIV'},
#  {'name': 'Facebook, Inc.', 'ticker': 'FB'},
#  {'name': 'Fastenal Co', 'ticker': 'FAST'},
#  {'name': 'Federal Realty Investment Trust', 'ticker': 'FRT'},
#  {'name': 'FedEx Corporation', 'ticker': 'FDX'},
#  {'name': 'Fidelity National Information Services', 'ticker': 'FIS'},
#  {'name': 'Fifth Third Bancorp', 'ticker': 'FITB'},
#  {'name': 'FirstEnergy Corp', 'ticker': 'FE'},
#  {'name': 'Fiserv Inc', 'ticker': 'FISV'},
#  {'name': 'FLIR Systems', 'ticker': 'FLIR'},
#  {'name': 'Flowserve Corporation', 'ticker': 'FLS'},
#  {'name': 'Fluor Corp.', 'ticker': 'FLR'},
#  {'name': 'FMC Corporation', 'ticker': 'FMC'},
#  {'name': 'Foot Locker Inc', 'ticker': 'FL'},
#  {'name': 'Ford Motor', 'ticker': 'F'},
#  {'name': 'Fortive Corp', 'ticker': 'FTV'},
#  {'name': 'Fortune Brands Home & Security', 'ticker': 'FBHS'},
#  {'name': 'Franklin Resources', 'ticker': 'BEN'},
#  {'name': 'Freeport-McMoRan Inc.', 'ticker': 'FCX'},
#  {'name': 'Gap Inc.', 'ticker': 'GPS'},
#  {'name': 'Garmin Ltd.', 'ticker': 'GRMN'},
#  {'name': 'Gartner Inc', 'ticker': 'IT'},
#  {'name': 'General Dynamics', 'ticker': 'GD'},
#  {'name': 'General Electric', 'ticker': 'GE'},
#  {'name': 'General Growth Properties Inc.', 'ticker': 'GGP'},
#  {'name': 'General Mills', 'ticker': 'GIS'},
#  {'name': 'General Motors', 'ticker': 'GM'},
#  {'name': 'Genuine Parts', 'ticker': 'GPC'},
#  {'name': 'Gilead Sciences', 'ticker': 'GILD'},
#  {'name': 'Global Payments Inc.', 'ticker': 'GPN'},
#  {'name': 'Goldman Sachs Group', 'ticker': 'GS'},
#  {'name': 'Goodyear Tire & Rubber', 'ticker': 'GT'},
#  {'name': 'Grainger (W.W.) Inc.', 'ticker': 'GWW'},
#  {'name': 'Halliburton Co.', 'ticker': 'HAL'},
#  {'name': 'Hanesbrands Inc', 'ticker': 'HBI'},
#  {'name': 'Harley-Davidson', 'ticker': 'HOG'},
#  {'name': 'Harris Corporation', 'ticker': 'HRS'},
#  {'name': 'Hartford Financial Svc.Gp.', 'ticker': 'HIG'},
#  {'name': 'Hasbro Inc.', 'ticker': 'HAS'},
#  {'name': 'HCA Holdings', 'ticker': 'HCA'},
#  {'name': 'HCP Inc.', 'ticker': 'HCP'},
#  {'name': 'Helmerich & Payne', 'ticker': 'HP'},
#  {'name': 'Henry Schein', 'ticker': 'HSIC'},
#  {'name': 'Hess Corporation', 'ticker': 'HES'},
#  {'name': 'Hewlett Packard Enterprise', 'ticker': 'HPE'},
#  {'name': 'Hilton Worldwide Holdings Inc', 'ticker': 'HLT'},
#  {'name': 'Hologic', 'ticker': 'HOLX'},
#  {'name': 'Home Depot', 'ticker': 'HD'},
#  {'name': "Honeywell Int'l Inc.", 'ticker': 'HON'},
#  {'name': 'Hormel Foods Corp.', 'ticker': 'HRL'},
#  {'name': 'Host Hotels & Resorts', 'ticker': 'HST'},
#  {'name': 'HP Inc.', 'ticker': 'HPQ'},
#  {'name': 'Humana Inc.', 'ticker': 'HUM'},
#  {'name': 'Huntington Bancshares', 'ticker': 'HBAN'},
#  {'name': 'Huntington Ingalls Industries', 'ticker': 'HII'},
#  {'name': 'IDEXX Laboratories', 'ticker': 'IDXX'},
#  {'name': 'IHS Markit Ltd.', 'ticker': 'INFO'},
#  {'name': 'Illinois Tool Works', 'ticker': 'ITW'},
#  {'name': 'Illumina Inc', 'ticker': 'ILMN'},
#  {'name': 'Incyte', 'ticker': 'INCY'},
#  {'name': 'Ingersoll-Rand PLC', 'ticker': 'IR'},
#  {'name': 'Intel Corp.', 'ticker': 'INTC'},
#  {'name': 'Intercontinental Exchange', 'ticker': 'ICE'},
#  {'name': 'International Business Machines', 'ticker': 'IBM'},
#  {'name': 'International Paper', 'ticker': 'IP'},
#  {'name': 'Interpublic Group', 'ticker': 'IPG'},
#  {'name': 'Intl Flavors & Fragrances', 'ticker': 'IFF'},
#  {'name': 'Intuit Inc.', 'ticker': 'INTU'},
#  {'name': 'Intuitive Surgical Inc.', 'ticker': 'ISRG'},
#  {'name': 'Invesco Ltd.', 'ticker': 'IVZ'},
#  {'name': 'IPG Photonics Corp.', 'ticker': 'IPGP'},
#  {'name': 'IQVIA Holdings Inc.', 'ticker': 'IQV'},
#  {'name': 'Iron Mountain Incorporated', 'ticker': 'IRM'},
#  {'name': 'J. B. Hunt Transport Services', 'ticker': 'JBHT'},
#  {'name': 'Jacobs Engineering Group', 'ticker': 'JEC'},
#  {'name': 'JM Smucker', 'ticker': 'SJM'},
#  {'name': 'Johnson & Johnson', 'ticker': 'JNJ'},
#  {'name': 'Johnson Controls International', 'ticker': 'JCI'},
#  {'name': 'JPMorgan Chase & Co.', 'ticker': 'JPM'},
#  {'name': 'Juniper Networks', 'ticker': 'JNPR'},
#  {'name': 'Kansas City Southern', 'ticker': 'KSU'},
#  {'name': 'Kellogg Co.', 'ticker': 'K'},
#  {'name': 'KeyCorp', 'ticker': 'KEY'},
#  {'name': 'Kimberly-Clark', 'ticker': 'KMB'},
#  {'name': 'Kimco Realty', 'ticker': 'KIM'},
#  {'name': 'Kinder Morgan', 'ticker': 'KMI'},
#  {'name': 'KLA-Tencor Corp.', 'ticker': 'KLAC'},
#  {'name': "Kohl's Corp.", 'ticker': 'KSS'},
#  {'name': 'Kraft Heinz Co', 'ticker': 'KHC'},
#  {'name': 'Kroger Co.', 'ticker': 'KR'},
#  {'name': 'L Brands Inc.', 'ticker': 'LB'},
#  {'name': 'L-3 Communications Holdings', 'ticker': 'LLL'},
#  {'name': 'Laboratory Corp. of America Holding', 'ticker': 'LH'},
#  {'name': 'Lam Research', 'ticker': 'LRCX'},
#  {'name': 'Leggett & Platt', 'ticker': 'LEG'},
#  {'name': 'Lennar Corp.', 'ticker': 'LEN'},
#  {'name': 'Leucadia National Corp.', 'ticker': 'LUK'},
#  {'name': 'Lilly (Eli) & Co.', 'ticker': 'LLY'},
#  {'name': 'Lincoln National', 'ticker': 'LNC'},
#  {'name': 'LKQ Corporation', 'ticker': 'LKQ'},
#  {'name': 'Lockheed Martin Corp.', 'ticker': 'LMT'},
#  {'name': 'Loews Corp.', 'ticker': 'L'},
#  {'name': "Lowe's Cos.", 'ticker': 'LOW'},
#  {'name': 'LyondellBasell', 'ticker': 'LYB'},
#  {'name': 'M&T Bank Corp.', 'ticker': 'MTB'},
#  {'name': 'Macerich', 'ticker': 'MAC'},
#  {'name': "Macy's Inc.", 'ticker': 'M'},
#  {'name': 'Marathon Oil Corp.', 'ticker': 'MRO'},
#  {'name': 'Marathon Petroleum', 'ticker': 'MPC'},
#  {'name': "Marriott Int'l.", 'ticker': 'MAR'},
#  {'name': 'Marsh & McLennan', 'ticker': 'MMC'},
#  {'name': 'Martin Marietta Materials', 'ticker': 'MLM'},
#  {'name': 'Masco Corp.', 'ticker': 'MAS'},
#  {'name': 'Mastercard Inc.', 'ticker': 'MA'},
#  {'name': 'Mattel Inc.', 'ticker': 'MAT'},
#  {'name': 'McCormick & Co.', 'ticker': 'MKC'},
#  {'name': "McDonald's Corp.", 'ticker': 'MCD'},
#  {'name': 'McKesson Corp.', 'ticker': 'MCK'},
#  {'name': 'Medtronic plc', 'ticker': 'MDT'},
#  {'name': 'Merck & Co.', 'ticker': 'MRK'},
#  {'name': 'MetLife Inc.', 'ticker': 'MET'},
#  {'name': 'Mettler Toledo', 'ticker': 'MTD'},
#  {'name': 'MGM Resorts International', 'ticker': 'MGM'},
#  {'name': 'Michael Kors Holdings', 'ticker': 'KORS'},
#  {'name': 'Microchip Technology', 'ticker': 'MCHP'},
#  {'name': 'Micron Technology', 'ticker': 'MU'},
#  {'name': 'Microsoft Corp.', 'ticker': 'MSFT'},
#  {'name': 'Mid-America Apartments', 'ticker': 'MAA'},
#  {'name': 'Mohawk Industries', 'ticker': 'MHK'},
#  {'name': 'Molson Coors Brewing Company', 'ticker': 'TAP'},
#  {'name': 'Mondelez International', 'ticker': 'MDLZ'},
#  {'name': 'Monsanto Co.', 'ticker': 'MON'},
#  {'name': 'Monster Beverage', 'ticker': 'MNST'},
#  {'name': "Moody's Corp", 'ticker': 'MCO'},
#  {'name': 'Morgan Stanley', 'ticker': 'MS'},
#  {'name': 'Motorola Solutions Inc.', 'ticker': 'MSI'},
#  {'name': 'Mylan N.V.', 'ticker': 'MYL'},
#  {'name': 'Nasdaq, Inc.', 'ticker': 'NDAQ'},
#  {'name': 'National Oilwell Varco Inc.', 'ticker': 'NOV'},
#  {'name': 'Navient', 'ticker': 'NAVI'},
#  {'name': 'Nektar Therapeutics', 'ticker': 'NKTR'},
#  {'name': 'NetApp', 'ticker': 'NTAP'},
#  {'name': 'Netflix Inc.', 'ticker': 'NFLX'},
#  {'name': 'Newell Brands', 'ticker': 'NWL'},
#  {'name': 'Newfield Exploration Co', 'ticker': 'NFX'},
#  {'name': 'Newmont Mining Corporation', 'ticker': 'NEM'},
#  {'name': 'News Corp. Class A', 'ticker': 'NWSA'},
#  {'name': 'News Corp. Class B', 'ticker': 'NWS'},
#  {'name': 'NextEra Energy', 'ticker': 'NEE'},
#  {'name': 'Nielsen Holdings', 'ticker': 'NLSN'},
#  {'name': 'Nike', 'ticker': 'NKE'},
#  {'name': 'NiSource Inc.', 'ticker': 'NI'},
#  {'name': 'Noble Energy Inc', 'ticker': 'NBL'},
#  {'name': 'Nordstrom', 'ticker': 'JWN'},
#  {'name': 'Norfolk Southern Corp.', 'ticker': 'NSC'},
#  {'name': 'Northern Trust Corp.', 'ticker': 'NTRS'},
#  {'name': 'Northrop Grumman Corp.', 'ticker': 'NOC'},
#  {'name': 'Norwegian Cruise Line', 'ticker': 'NCLH'},
#  {'name': 'NRG Energy', 'ticker': 'NRG'},
#  {'name': 'Nucor Corp.', 'ticker': 'NUE'},
#  {'name': 'Nvidia Corporation', 'ticker': 'NVDA'},
#  {'name': "O'Reilly Automotive", 'ticker': 'ORLY'},
#  {'name': 'Occidental Petroleum', 'ticker': 'OXY'},
#  {'name': 'Omnicom Group', 'ticker': 'OMC'},
#  {'name': 'ONEOK', 'ticker': 'OKE'},
#  {'name': 'Oracle Corp.', 'ticker': 'ORCL'},
#  {'name': 'PACCAR Inc.', 'ticker': 'PCAR'},
#  {'name': 'Packaging Corporation of America', 'ticker': 'PKG'},
#  {'name': 'Parker-Hannifin', 'ticker': 'PH'},
#  {'name': 'Paychex Inc.', 'ticker': 'PAYX'},
#  {'name': 'PayPal', 'ticker': 'PYPL'},
#  {'name': 'Pentair Ltd.', 'ticker': 'PNR'},
#  {'name': "People's United Financial", 'ticker': 'PBCT'},
#  {'name': 'PepsiCo Inc.', 'ticker': 'PEP'},
#  {'name': 'PerkinElmer', 'ticker': 'PKI'},
#  {'name': 'Perrigo', 'ticker': 'PRGO'},
#  {'name': 'Pfizer Inc.', 'ticker': 'PFE'},
#  {'name': 'PG&E Corp.', 'ticker': 'PCG'},
#  {'name': 'Philip Morris International', 'ticker': 'PM'},
#  {'name': 'Phillips 66', 'ticker': 'PSX'},
#  {'name': 'Pinnacle West Capital', 'ticker': 'PNW'},
#  {'name': 'Pioneer Natural Resources', 'ticker': 'PXD'},
#  {'name': 'PNC Financial Services', 'ticker': 'PNC'},
#  {'name': 'Polo Ralph Lauren Corp.', 'ticker': 'RL'},
#  {'name': 'PPG Industries', 'ticker': 'PPG'},
#  {'name': 'PPL Corp.', 'ticker': 'PPL'},
#  {'name': 'Praxair Inc.', 'ticker': 'PX'},
#  {'name': 'Principal Financial Group', 'ticker': 'PFG'},
#  {'name': 'Procter & Gamble', 'ticker': 'PG'},
#  {'name': 'Progressive Corp.', 'ticker': 'PGR'},
#  {'name': 'Prologis', 'ticker': 'PLD'},
#  {'name': 'Prudential Financial', 'ticker': 'PRU'},
#  {'name': 'Public Serv. Enterprise Inc.', 'ticker': 'PEG'},
#  {'name': 'Public Storage', 'ticker': 'PSA'},
#  {'name': 'Pulte Homes Inc.', 'ticker': 'PHM'},
#  {'name': 'PVH Corp.', 'ticker': 'PVH'},
#  {'name': 'Qorvo', 'ticker': 'QRVO'},
#  {'name': 'QUALCOMM Inc.', 'ticker': 'QCOM'},
#  {'name': 'Quanta Services Inc.', 'ticker': 'PWR'},
#  {'name': 'Quest Diagnostics', 'ticker': 'DGX'},
#  {'name': 'Range Resources Corp.', 'ticker': 'RRC'},
#  {'name': 'Raymond James Financial Inc.', 'ticker': 'RJF'},
#  {'name': 'Raytheon Co.', 'ticker': 'RTN'},
#  {'name': 'Realty Income Corporation', 'ticker': 'O'},
#  {'name': 'Red Hat Inc.', 'ticker': 'RHT'},
#  {'name': 'Regency Centers Corporation', 'ticker': 'REG'},
#  {'name': 'Regeneron', 'ticker': 'REGN'},
#  {'name': 'Regions Financial Corp.', 'ticker': 'RF'},
#  {'name': 'Republic Services Inc', 'ticker': 'RSG'},
#  {'name': 'ResMed', 'ticker': 'RMD'},
#  {'name': 'Robert Half International', 'ticker': 'RHI'},
#  {'name': 'Rockwell Automation Inc.', 'ticker': 'ROK'},
#  {'name': 'Rockwell Collins', 'ticker': 'COL'},
#  {'name': 'Roper Technologies', 'ticker': 'ROP'},
#  {'name': 'Ross Stores', 'ticker': 'ROST'},
#  {'name': 'Royal Caribbean Cruises Ltd', 'ticker': 'RCL'},
#  {'name': 'S&P Global, Inc.', 'ticker': 'SPGI'},
#  {'name': 'Salesforce.com', 'ticker': 'CRM'},
#  {'name': 'SBA Communications', 'ticker': 'SBAC'},
#  {'name': 'SCANA Corp', 'ticker': 'SCG'},
#  {'name': 'Schlumberger Ltd.', 'ticker': 'SLB'},
#  {'name': 'Seagate Technology', 'ticker': 'STX'},
#  {'name': 'Sealed Air', 'ticker': 'SEE'},
#  {'name': 'Sempra Energy', 'ticker': 'SRE'},
#  {'name': 'Sherwin-Williams', 'ticker': 'SHW'},
#  {'name': 'Simon Property Group Inc', 'ticker': 'SPG'},
#  {'name': 'Skyworks Solutions', 'ticker': 'SWKS'},
#  {'name': 'SL Green Realty', 'ticker': 'SLG'},
#  {'name': 'Snap-On Inc.', 'ticker': 'SNA'},
#  {'name': 'Southern Co.', 'ticker': 'SO'},
#  {'name': 'Southwest Airlines', 'ticker': 'LUV'},
#  {'name': 'Stanley Black & Decker', 'ticker': 'SWK'},
#  {'name': 'Starbucks Corp.', 'ticker': 'SBUX'},
#  {'name': 'State Street Corp.', 'ticker': 'STT'},
#  {'name': 'Stericycle Inc', 'ticker': 'SRCL'},
#  {'name': 'Stryker Corp.', 'ticker': 'SYK'},
#  {'name': 'SunTrust Banks', 'ticker': 'STI'},
#  {'name': 'SVB Financial', 'ticker': 'SIVB'},
#  {'name': 'Symantec Corp.', 'ticker': 'SYMC'},
#  {'name': 'Synchrony Financial', 'ticker': 'SYF'},
#  {'name': 'Synopsys Inc.', 'ticker': 'SNPS'},
#  {'name': 'Sysco Corp.', 'ticker': 'SYY'},
#  {'name': 'T. Rowe Price Group', 'ticker': 'TROW'},
#  {'name': 'Take-Two Interactive', 'ticker': 'TTWO'},
#  {'name': 'Tapestry, Inc.', 'ticker': 'TPR'},
#  {'name': 'Target Corp.', 'ticker': 'TGT'},
#  {'name': 'TE Connectivity Ltd.', 'ticker': 'TEL'},
#  {'name': 'TechnipFMC', 'ticker': 'FTI'},
#  {'name': 'Texas Instruments', 'ticker': 'TXN'},
#  {'name': 'Textron Inc.', 'ticker': 'TXT'},
#  {'name': 'The Bank of New York Mellon Corp.', 'ticker': 'BK'},
#  {'name': 'The Clorox Company', 'ticker': 'CLX'},
#  {'name': 'The Cooper Companies', 'ticker': 'COO'},
#  {'name': 'The Hershey Company', 'ticker': 'HSY'},
#  {'name': 'The Mosaic Company', 'ticker': 'MOS'},
#  {'name': 'The Travelers Companies Inc.', 'ticker': 'TRV'},
#  {'name': 'The Walt Disney Company', 'ticker': 'DIS'},
#  {'name': 'Thermo Fisher Scientific', 'ticker': 'TMO'},
#  {'name': 'Tiffany & Co.', 'ticker': 'TIF'},
#  {'name': 'Time Warner Inc.', 'ticker': 'TWX'},
#  {'name': 'TJX Companies Inc.', 'ticker': 'TJX'},
#  {'name': 'Torchmark Corp.', 'ticker': 'TMK'},
#  {'name': 'Total System Services', 'ticker': 'TSS'},
#  {'name': 'Tractor Supply Company', 'ticker': 'TSCO'},
#  {'name': 'TransDigm Group', 'ticker': 'TDG'},
#  {'name': 'TripAdvisor', 'ticker': 'TRIP'},
#  {'name': 'Twenty-First Century Fox Class A', 'ticker': 'FOXA'},
#  {'name': 'Twenty-First Century Fox Class B', 'ticker': 'FOX'},
#  {'name': 'Tyson Foods', 'ticker': 'TSN'},
#  {'name': 'U.S. Bancorp', 'ticker': 'USB'},
#  {'name': 'UDR Inc', 'ticker': 'UDR'},
#  {'name': 'Ulta Beauty', 'ticker': 'ULTA'},
#  {'name': 'Under Armour Class A', 'ticker': 'UAA'},
#  {'name': 'Under Armour Class C', 'ticker': 'UA'},
#  {'name': 'Union Pacific', 'ticker': 'UNP'},
#  {'name': 'United Continental Holdings', 'ticker': 'UAL'},
#  {'name': 'United Health Group Inc.', 'ticker': 'UNH'},
#  {'name': 'United Parcel Service', 'ticker': 'UPS'},
#  {'name': 'United Rentals, Inc.', 'ticker': 'URI'},
#  {'name': 'United Technologies', 'ticker': 'UTX'},
#  {'name': 'Universal Health Services, Inc.', 'ticker': 'UHS'},
#  {'name': 'Unum Group', 'ticker': 'UNM'},
#  {'name': 'V.F. Corp.', 'ticker': 'VFC'},
#  {'name': 'Valero Energy', 'ticker': 'VLO'},
#  {'name': 'Varian Medical Systems', 'ticker': 'VAR'},
#  {'name': 'Ventas Inc', 'ticker': 'VTR'},
#  {'name': 'Verisign Inc.', 'ticker': 'VRSN'},
#  {'name': 'Verisk Analytics', 'ticker': 'VRSK'},
#  {'name': 'Verizon Communications', 'ticker': 'VZ'},
#  {'name': 'Vertex Pharmaceuticals Inc', 'ticker': 'VRTX'},
#  {'name': 'Viacom Inc.', 'ticker': 'VIAB'},
#  {'name': 'Visa Inc.', 'ticker': 'V'},
#  {'name': 'Vornado Realty Trust', 'ticker': 'VNO'},
#  {'name': 'Vulcan Materials', 'ticker': 'VMC'},
#  {'name': 'Wal-Mart Stores', 'ticker': 'WMT'},
#  {'name': 'Walgreens Boots Alliance', 'ticker': 'WBA'},
#  {'name': 'Waste Management Inc.', 'ticker': 'WM'},
#  {'name': 'Waters Corporation', 'ticker': 'WAT'},
#  {'name': 'Wec Energy Group Inc', 'ticker': 'WEC'},
#  {'name': 'Wells Fargo', 'ticker': 'WFC'},
#  {'name': 'Welltower Inc.', 'ticker': 'WELL'},
#  {'name': 'Western Digital', 'ticker': 'WDC'},
#  {'name': 'Western Union Co', 'ticker': 'WU'},
#  {'name': 'WestRock Company', 'ticker': 'WRK'},
#  {'name': 'Weyerhaeuser Corp.', 'ticker': 'WY'},
#  {'name': 'Whirlpool Corp.', 'ticker': 'WHR'},
#  {'name': 'Williams Cos.', 'ticker': 'WMB'},
#  {'name': 'Willis Towers Watson', 'ticker': 'WLTW'},
#  {'name': 'Wyndham Worldwide', 'ticker': 'WYN'},
#  {'name': 'Wynn Resorts Ltd', 'ticker': 'WYNN'},
#  {'name': 'Xcel Energy Inc', 'ticker': 'XEL'},
#  {'name': 'Xerox Corp.', 'ticker': 'XRX'},
#  {'name': 'Xilinx Inc', 'ticker': 'XLNX'},
#  {'name': 'XL Capital', 'ticker': 'XL'},
#  {'name': 'Xylem Inc.', 'ticker': 'XYL'},
#  {'name': 'Yum! Brands Inc', 'ticker': 'YUM'},
#  {'name': 'Zimmer Biomet Holdings', 'ticker': 'ZBH'},
#  {'name': 'Zions Bancorp', 'ticker': 'ZION'},
#  {'name': 'Zoetis', 'ticker': 'ZTS'}]

# %%
for stock in spx_stonks:
    get_stock_data_json(stock['ticker'])
stock_list = json.dumps(stocks)
with open('./client/public/Data/stocks.json', 'w') as f:
    f.write(stock_list)
